# %% [markdown]
# # setting up camels directory

# %% [markdown]
# DO NOT RUN THIS SECTION!

# %%
import os, shutil
files = os.listdir("/global/cfs/cdirs/des/shubh/timsim/simim_resources/simulations/camels_CV_0")
files[:5], len(files)
# Out:
# (['fof_subhalo_tab_002.hdf5',
#   'fof_subhalo_tab_005.hdf5',
#   'fof_subhalo_tab_016.hdf5',
#   'fof_subhalo_tab_030.hdf5',
#   'fof_subhalo_tab_000.hdf5'],
#  34)

# %%
# set the source and destination directories
src_dir = "/global/cfs/cdirs/des/shubh/timsim/simim_resources/simulations/camels_CV_0/"
dest_dir = "/global/cfs/cdirs/des/shubh/timsim/simim_resources/simulations/camels_CV_0/raw/groups_"

# iterate over all the files in the source directory
for filename in os.listdir(src_dir):
    
    # check if the file is of the desired format
    if filename.startswith("fof_subhalo_tab_") and filename.endswith(".hdf5"):
        
        # extract the three digit number from the filename
        num = filename[17:20]
        
        # create the destination directory if it doesn't exist
        dest_subdir = dest_dir + num
        os.makedirs(dest_subdir, exist_ok=True)
        
        # move the file to the destination directory
        src_file = os.path.join(src_dir, filename)
        dest_file = os.path.join(dest_subdir, filename)
        shutil.move(src_file, dest_file)

# %%
files = os.listdir("/global/cfs/cdirs/des/shubh/timsim/simim_resources/simulations/camels_CV_0")
files
# Out:
# ['raw']

# %%
dest_dir = "/global/cfs/cdirs/des/shubh/timsim/simim_resources/simulations/camels_CV_0/raw/"

# iterate over all the files in the source directory
for foldname in os.listdir(dest_dir):
    print(foldname, "0"+foldname[7:-1])
    os.rename(dest_dir+foldname, dest_dir+"groups_0"+foldname[7:-1])
# Out:
# groups_26. 026
# groups_08. 008
# groups_21. 021
# groups_02. 002
# groups_14. 014
# groups_27. 027
# groups_28. 028
# groups_05. 005
# groups_18. 018
# groups_01. 001
# groups_31. 031
# groups_13. 013
# groups_03. 003
# groups_30. 030
# groups_20. 020
# groups_29. 029
# groups_19. 019
# groups_15. 015
# groups_07. 007
# groups_12. 012
# groups_23. 023
# groups_25. 025
# groups_16. 016
# groups_06. 006
# groups_22. 022
# groups_17. 017
# groups_10. 010
# groups_24. 024
# groups_32. 032
# groups_04. 004
# groups_33. 033
# groups_11. 011
# groups_09. 009
# groups_00. 000

# %%
files = os.listdir("/global/cfs/cdirs/des/shubh/timsim/simim_resources/simulations/camels_CV_0/raw")
files[:5], len(files)
# Out:
# (['groups_010', 'groups_015', 'groups_013', 'groups_006', 'groups_014'], 34)

# %% [markdown]
# # setting up meta file

# %%
import h5py, os

camels_dir = "/global/cfs/cdirs/des/shubh/camels"

os.listdir(camels_dir + "/Sims/IllustrisTNG/CV_0/")[:5]
# Out:
# ['snap_025.hdf5',
#  'snap_006.hdf5',
#  'snap_020.hdf5',
#  'snap_000.hdf5',
#  'snap_001.hdf5']

# %%
fof_path = "/global/cfs/cdirs/des/shubh/camels/~camels/FOF_Subfind/IllustrisTNG/LH_832/fof_subhalo_tab_000.hdf5"
# fof_path = "/global/cfs/cdirs/des/shubh/camels/Sims/IllustrisTNG/LH_15/snap_000.hdf5"
fof_file = h5py.File(fof_path, 'r')

# %%
list(fof_file['Header'].attrs.keys())
# Out:
# ['BoxSize',
#  'FlagDoubleprecision',
#  'Git_commit',
#  'Git_date',
#  'HubbleParam',
#  'Ngroups_ThisFile',
#  'Ngroups_Total',
#  'Nids_ThisFile',
#  'Nids_Total',
#  'Nsubgroups_ThisFile',
#  'Nsubgroups_Total',
#  'NumFiles',
#  'Omega0',
#  'OmegaLambda',
#  'Redshift',
#  'Time']

# %%
fof_file['Header'].attrs['Omega0'], fof_file['Header'].attrs['OmegaLambda'], fof_file['Header'].attrs['OmegaBaryon']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 fof_file['Header'].attrs['Omega0'], fof_file['Header'].attrs['OmegaLambda'], fof_file['Header'].attrs['OmegaBaryon']
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~/.conda/envs/simtim/lib/python3.9/site-packages/h5py/_hl/attrs.py:56, in AttributeManager.__getitem__(self, name)
#      52 @with_phil
#      53 def __getitem__(self, name):
#      54     """ Read the value of an attribute.
#      55     """
# ---> 56     attr = h5a.open(self._id, self._e(name))
#      57     shape = attr.shape
#      59     # shape is None for empty dataspaces
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5a.pyx:80, in h5py.h5a.open()
#
# KeyError: "Can't open attribute (can't locate attribute: 'OmegaBaryon')"

# %%
fof_file['Header'].attrs['HubbleParam']
# Out:
# 0.6711

# %%
list(map(lambda x: (x, fof_file['Header'].attrs[x]), fof_file['Header'].attrs.keys()))
# Out:
# [('BoxSize', 25000.0),
#  ('FlagDoubleprecision', 0),
#  ('Git_commit', b'4ab97a2c5659df3e83e01c53f8142816fc0db675'),
#  ('Git_date', b'Tue May 3 10:27:55 2016 +0200'),
#  ('HubbleParam', 0.6711),
#  ('Ngroups_ThisFile', 430),
#  ('Ngroups_Total', 430),
#  ('Nids_ThisFile', 37998),
#  ('Nids_Total', 37998),
#  ('Nsubgroups_ThisFile', 374),
#  ('Nsubgroups_Total', 374),
#  ('NumFiles', 1),
#  ('Omega0', 0.109),
#  ('OmegaLambda', 0.891),
#  ('Redshift', 5.977616828479627),
#  ('Time', 0.14331540762147194)]

# %% [markdown]
# # sim interface

# %%
import os
os._exit(0)

# %%
import numpy as np
import simim.siminterface as sim

# %%
cat = sim.illustris.illustris_catalogs('camels/CV_0')
# Out:
# /global/cfs/cdirs/des/shubh/timsim/CosmoIM/simim/simim/siminterface/_rawsiminterface.py:151: UserWarning: No meta data for this simulation is available - run .download_meta
#   warnings.warn("No meta data for this simulation is available - run .download_meta")

# %%
cat.download_meta_camels(redownload=True)

# %%
cat.format(remake=True,basic=False)
# Out:
# Formatting snap 0
# Formatting snap 1
# Formatting snap 2
# Formatting snap 3
# Formatting snap 4
# Formatting snap 5
# Formatting snap 6
# Formatting snap 7
# Formatting snap 8
# Formatting snap 9
# Formatting snap 10
# Formatting snap 11
# Formatting snap 12
# Formatting snap 13
# Formatting snap 14
# Formatting snap 15
# Formatting snap 16
# Formatting snap 17
# Formatting snap 18
# Formatting snap 19
# Formatting snap 20
# Formatting snap 21
# Formatting snap 22
# Formatting snap 23
# Formatting snap 24
# Formatting snap 25
# Formatting snap 26
# Formatting snap 27
# Formatting snap 28
# Formatting snap 29
# Formatting snap 30
# Formatting snap 31
# Formatting snap 32
# Formatting snap 33

# %% [markdown]
# # sim handler

# %%
import os
os._exit(0)

# %%
import simim.siminterface as sim
simhandler = sim.simhandler.simhandler('camels/CV_0')

# %%
print("The halo catalog fields for this simulation are: "+', '.join([f for f in simhandler.extract_snap_keys()]))
# Out:
# The halo catalog fields for this simulation are: bhmass, bhmdot, cm_x, cm_y, cm_z, m_bh, m_bh_2hr, m_bh_hr, m_bh_maxr, m_dm, m_dm_2hr, m_dm_hr, m_dm_maxr, m_gas, m_gas_2hr, m_gas_hr, m_gas_maxr, m_stars_wind, m_stars_wind_2hr, m_stars_wind_hr, m_stars_wind_maxr, m_tracers, m_tracers_2hr, m_tracers_hr, m_tracers_maxr, mass, mass_2hr, mass_hr, mass_maxr, met, met_hr, met_maxr, met_stellar, met_stellar_hr, met_stellar_maxr, phot_B, phot_K, phot_U, phot_V, phot_g, phot_i, phot_r, phot_z, pos_x, pos_y, pos_z, r_hm, r_vmax, sfr, sfr_2hr, sfr_maxr, spin_x, spin_y, spin_z, v_x, v_y, v_z, vdisp, vmax

# %%
z = 1.0
print("The snapshot closest to redshift {:.1f} has index {}".format(z,simhandler.z_to_snap(z)))
# Out:
# The snapshot closest to redshift 1.0 has index 18

# %%
snaphandler = simhandler.get_snap(simhandler.z_to_snap(z))
# Equivalently we could have used
# snaphandler = simhandler.get_snap(50)

# %%
print("The halo catalog fields for this snapshot are: "+', '.join([f for f in snaphandler.extract_keys()]))
# Out:
# The halo catalog fields for this snapshot are: bhmass, bhmdot, cm_x, cm_y, cm_z, m_bh, m_bh_2hr, m_bh_hr, m_bh_maxr, m_dm, m_dm_2hr, m_dm_hr, m_dm_maxr, m_gas, m_gas_2hr, m_gas_hr, m_gas_maxr, m_stars_wind, m_stars_wind_2hr, m_stars_wind_hr, m_stars_wind_maxr, m_tracers, m_tracers_2hr, m_tracers_hr, m_tracers_maxr, mass, mass_2hr, mass_hr, mass_maxr, met, met_hr, met_maxr, met_stellar, met_stellar_hr, met_stellar_maxr, phot_B, phot_K, phot_U, phot_V, phot_g, phot_i, phot_r, phot_z, pos_x, pos_y, pos_z, r_hm, r_vmax, sfr, sfr_2hr, sfr_maxr, spin_x, spin_y, spin_z, v_x, v_y, v_z, vdisp, vmax

# %%
print("The loaded fields for this snapshot are: "+', '.join([f for f in snaphandler.extract_keys(set='loaded')]))
print("The saved fields for this snapshot are: "+', '.join([f for f in snaphandler.extract_keys(set='saved')]))
print("The new fields for this snapshot are: "+', '.join([f for f in snaphandler.extract_keys(set='generated')]))
# Out:
# The loaded fields for this snapshot are:
# The saved fields for this snapshot are: bhmass, bhmdot, cm_x, cm_y, cm_z, m_bh, m_bh_2hr, m_bh_hr, m_bh_maxr, m_dm, m_dm_2hr, m_dm_hr, m_dm_maxr, m_gas, m_gas_2hr, m_gas_hr, m_gas_maxr, m_stars_wind, m_stars_wind_2hr, m_stars_wind_hr, m_stars_wind_maxr, m_tracers, m_tracers_2hr, m_tracers_hr, m_tracers_maxr, mass, mass_2hr, mass_hr, mass_maxr, met, met_hr, met_maxr, met_stellar, met_stellar_hr, met_stellar_maxr, phot_B, phot_K, phot_U, phot_V, phot_g, phot_i, phot_r, phot_z, pos_x, pos_y, pos_z, r_hm, r_vmax, sfr, sfr_2hr, sfr_maxr, spin_x, spin_y, spin_z, v_x, v_y, v_z, vdisp, vmax
# The new fields for this snapshot are:

# %%
snaphandler.load_property('pos_x','pos_y','pos_z')

# %%
print("The loaded fields for this snapshot are: "+', '.join([f for f in snaphandler.extract_keys(set='loaded')]))
print("The saved fields for this snapshot are: "+', '.join([f for f in snaphandler.extract_keys(set='saved')]))
print("The new fields for this snapshot are: "+', '.join([f for f in snaphandler.extract_keys(set='generated')]))
# Out:
# The loaded fields for this snapshot are: pos_x, pos_y, pos_z
# The saved fields for this snapshot are: bhmass, bhmdot, cm_x, cm_y, cm_z, m_bh, m_bh_2hr, m_bh_hr, m_bh_maxr, m_dm, m_dm_2hr, m_dm_hr, m_dm_maxr, m_gas, m_gas_2hr, m_gas_hr, m_gas_maxr, m_stars_wind, m_stars_wind_2hr, m_stars_wind_hr, m_stars_wind_maxr, m_tracers, m_tracers_2hr, m_tracers_hr, m_tracers_maxr, mass, mass_2hr, mass_hr, mass_maxr, met, met_hr, met_maxr, met_stellar, met_stellar_hr, met_stellar_maxr, phot_B, phot_K, phot_U, phot_V, phot_g, phot_i, phot_r, phot_z, pos_x, pos_y, pos_z, r_hm, r_vmax, sfr, sfr_2hr, sfr_maxr, spin_x, spin_y, spin_z, v_x, v_y, v_z, vdisp, vmax
# The new fields for this snapshot are:

# %%
snaphandler.plot('pos_x','pos_y',axkws={'xlabel':'x-position [Mpc/h]','ylabel':'y-position [Mpc/h]','aspect':'equal'},plotkws={'marker':',','color':'k'})

# %%
snaphandler.set_property_range('pos_z',0,10) # Restrict catalog to only halos with pos_z<10 Mpc/h
snaphandler.plot('pos_x','pos_y',axkws={'xlabel':'x-position [Mpc/h]','ylabel':'y-position [Mpc/h]','aspect':'equal'},plotkws={'marker':',','color':'k'})

# %%
snaphandler.set_property_range('pos_x',0,10) # Restrict catalog to only halos with pos_x<10 Mpc/h
snaphandler.set_property_range('pos_y',0,10) # Restrict catalog to only halos with pos_y<10 Mpc/h
snaphandler.plot('pos_x','pos_y',axkws={'xlabel':'x-position [Mpc/h]','ylabel':'y-position [Mpc/h]','aspect':'equal','xlim':[0,75],'ylim':[0,75]},plotkws={'marker':',','color':'k'})

# %%
# Undo these cuts.
snaphandler.set_property_range()

# %%
import numpy as np
snaphandler.hist('mass',axkws={'xlabel':'Halo Mass [M$_\odot$/h]','xscale':'log','yscale':'log'}, plotkws={'bins':np.logspace(9,15,61)})

# %% [markdown]
# # add line props

# %%
import os
os._exit(0)

# %%
import numpy as np
import simim.siminterface as sim
from matplotlib import pyplot as plt

z_for_modeling = 2.4
wl_co = 2.60076e-3      # m
Lsun = 3.828e26         # W
Mpc = 3.0857e22         # m
c = 2.99792458e8        # m s^-1
kB = 1.3806e-23         # m^2 kg s^-2 K^-1
simhandler = sim.simhandler.simhandler('camels/CV_0')

snap = simhandler.get_snap(simhandler.z_to_snap(z_for_modeling))

# %%
from simim.lineprops.lineprops import prop_li_co,prop_behroozi_sfr
from simim.map import gridder

snap.set_property_range()
snap.make_property(prop_behroozi_sfr,rename='sfr_behroozi',other_kws={'scatter':False})
snap.make_property(prop_li_co,rename='LCO_ns',kw_remap={'sfr':'sfr_behroozi'},other_kws={'scatter_lco':False})

# %%
print("The loaded fields for this snapshot are: "+', '.join([f for f in snap.extract_keys(set='loaded')]))
print("The saved fields for this snapshot are: "+', '.join([f for f in snap.extract_keys(set='saved')]))
print("The new fields for this snapshot are: "+', '.join([f for f in snap.extract_keys(set='generated')]))
# Out:
# The loaded fields for this snapshot are: sfr_behroozi, LCO_ns
# The saved fields for this snapshot are: bhmass, bhmdot, cm_x, cm_y, cm_z, m_bh, m_bh_2hr, m_bh_hr, m_bh_maxr, m_dm, m_dm_2hr, m_dm_hr, m_dm_maxr, m_gas, m_gas_2hr, m_gas_hr, m_gas_maxr, m_stars_wind, m_stars_wind_2hr, m_stars_wind_hr, m_stars_wind_maxr, m_tracers, m_tracers_2hr, m_tracers_hr, m_tracers_maxr, mass, mass_2hr, mass_hr, mass_maxr, met, met_hr, met_maxr, met_stellar, met_stellar_hr, met_stellar_maxr, phot_B, phot_K, phot_U, phot_V, phot_g, phot_i, phot_r, phot_z, pos_x, pos_y, pos_z, r_hm, r_vmax, sfr, sfr_2hr, sfr_maxr, spin_x, spin_y, spin_z, v_x, v_y, v_z, vdisp, vmax
# The new fields for this snapshot are: sfr_behroozi, LCO_ns

# %%
from simim.lineprops.co import li16,lidz11,pullen13
from simim.lineprops.sfr import behroozi13

msun = np.logspace(9,13.5)
sfr = behroozi13(z_for_modeling,msun,scatter=False)
lco_li = li16(sfr,scatter_lco=False)

f_duty = .1/snap.cosmo.age(z_for_modeling).value
lco_lidz = lidz11(msun,f_duty,rand_f_duty=False)

lco_pullen = pullen13(msun,z_for_modeling,cosmo=snap.cosmo,rand_f_duty=False)

# Plot results
fig,ax = plt.subplots(figsize=(7,6))
ax.set(xlabel='M$_h$ [M$_\odot$]',ylabel='L$_\mathregular{CO}$ [L$_\odot$]',xscale='log',yscale='log',xlim=(1e9,10**13.5))
ax.grid()
ax.plot(msun,lco_li,lw=2,color='k',label='Li+16')
ax.plot(msun,lco_lidz,label='Lidz+11')
ax.plot(msun,lco_pullen,lw=2,label='Pullen+13')
ax.legend()
plt.show()

# %%
# Define a grid
pixel_size = .25
side_length = ((simhandler.box_edge_no_h) // pixel_size) * pixel_size      # This crops the box to have an integer number of pixels
center_point = [side_length/2,side_length/2,side_length/2]

# Compute some cosmological factors
xfactor = snap.cosmo.comoving_distance(z_for_modeling).value                         # Mpc / rad
yfactor = wl_co * (1+z_for_modeling)**2 / (1000*snap.cosmo.H(z_for_modeling).value)  # derivative of distance with respect to frequency in Mpc / Hz
dl = (1+z_for_modeling)*xfactor                                                      # luminosity distance to z in Mpc

# Convert flux to luminosity for each point
L_to_f = Lsun / (4*np.pi*(dl*Mpc)**2)                                                # Convert luminosity (Lsum) to flux (W/m^2)
f_to_i = xfactor**2*yfactor/pixel_size**3                                            # Convert flux (W/m^2) to intensity (W/m^2/Str/Hz)
i_to_T = ((1+z_for_modeling)*wl_co)**2 / (2*kB) * 1e6                                # Convert intensity (W/m^2/Str/Hz) to brightness temp (uK)
temps = snap.return_property('LCO_ns',in_h_units=False) * L_to_f * f_to_i * i_to_T

# Get object positions
x = snap.return_property('pos_x',in_h_units=False)
y = snap.return_property('pos_y',in_h_units=False)
z = snap.return_property('pos_z',in_h_units=False)
positions = np.array([x,y,z]).T

# Make the grid
grid = gridder(positions,temps,center_point=center_point,side_length=side_length,pixel_size=pixel_size,axunits='Mpc',gridunits='uK')

# %%
ps = grid.power_spectrum(in_place=False,normalize=True)

# Spherical average
bins = np.logspace(-3,3,61)
bin_centers = np.logspace(-2.95,2.95,60)
_,ps1d = ps.spherical_average(ax=[0,1,2],bins=bins)
ps1d = ps1d[:,0] / side_length**3                           # Normalize by volume
k = 2*np.pi * bin_centers
# Out:
# /global/cfs/cdirs/des/shubh/timsim/CosmoIM/simim/simim/map/gridder.py:1085: RuntimeWarning: invalid value encountered in divide
#   binned_averages /= binned_weights

# %%
# Plot the results
fig,ax = plt.subplots(1,2,figsize=(14,6),sharex=True)
fig.subplots_adjust(wspace=.4)
ax[0].set(xlabel='k [Mpc$^{-1}$]',ylabel='P(k) [$\mu$K$^2$ Mpc$^{3}$]',xscale='log',yscale='log')
ax[0].grid()
ax[0].plot(k,ps1d,lw=2,color='k')
ax[1].set(xlabel='k [Mpc$^{-1}$]',ylabel='k$^3$P(k)/2$\pi$ [$\mu$K$^2$]',xscale='log',yscale='log')
ax[1].plot(k,k**3/2/np.pi**2*ps1d,lw=2,color='k')
ax[1].grid()
plt.show()
