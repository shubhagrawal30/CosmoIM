# %% [markdown]
# # setting up camels directory

# %% [markdown]
# DO NOT RUN THIS SECTION!

# %%
import os, shutil
files = os.listdir("/global/cfs/cdirs/des/shubh/timsim/simim_resources/simulations/camels_CV_0")
files[:5], len(files)
# Out:
# (['fof_subhalo_tab_002.hdf5',
#   'fof_subhalo_tab_005.hdf5',
#   'fof_subhalo_tab_016.hdf5',
#   'fof_subhalo_tab_030.hdf5',
#   'fof_subhalo_tab_000.hdf5'],
#  34)

# %%
# set the source and destination directories
src_dir = "/global/cfs/cdirs/des/shubh/timsim/simim_resources/simulations/camels_CV_0/"
dest_dir = "/global/cfs/cdirs/des/shubh/timsim/simim_resources/simulations/camels_CV_0/raw/groups_"

# iterate over all the files in the source directory
for filename in os.listdir(src_dir):
    
    # check if the file is of the desired format
    if filename.startswith("fof_subhalo_tab_") and filename.endswith(".hdf5"):
        
        # extract the three digit number from the filename
        num = filename[17:20]
        
        # create the destination directory if it doesn't exist
        dest_subdir = dest_dir + num
        os.makedirs(dest_subdir, exist_ok=True)
        
        # move the file to the destination directory
        src_file = os.path.join(src_dir, filename)
        dest_file = os.path.join(dest_subdir, filename)
        shutil.move(src_file, dest_file)

# %%
files = os.listdir("/global/cfs/cdirs/des/shubh/timsim/simim_resources/simulations/camels_CV_0")
files
# Out:
# ['raw']

# %%
dest_dir = "/global/cfs/cdirs/des/shubh/timsim/simim_resources/simulations/camels_CV_0/raw/"

# iterate over all the files in the source directory
for foldname in os.listdir(dest_dir):
    print(foldname, "0"+foldname[7:-1])
    os.rename(dest_dir+foldname, dest_dir+"groups_0"+foldname[7:-1])
# Out:
# groups_26. 026
# groups_08. 008
# groups_21. 021
# groups_02. 002
# groups_14. 014
# groups_27. 027
# groups_28. 028
# groups_05. 005
# groups_18. 018
# groups_01. 001
# groups_31. 031
# groups_13. 013
# groups_03. 003
# groups_30. 030
# groups_20. 020
# groups_29. 029
# groups_19. 019
# groups_15. 015
# groups_07. 007
# groups_12. 012
# groups_23. 023
# groups_25. 025
# groups_16. 016
# groups_06. 006
# groups_22. 022
# groups_17. 017
# groups_10. 010
# groups_24. 024
# groups_32. 032
# groups_04. 004
# groups_33. 033
# groups_11. 011
# groups_09. 009
# groups_00. 000

# %%
files = os.listdir("/global/cfs/cdirs/des/shubh/timsim/simim_resources/simulations/camels_CV_0/raw")
files[:5], len(files)
# Out:
# (['groups_010', 'groups_015', 'groups_013', 'groups_006', 'groups_014'], 34)

# %% [markdown]
# # setting up meta file

# %%
import h5py, os

camels_dir = "/global/cfs/cdirs/des/shubh/camels"

os.listdir(camels_dir + "/Sims/IllustrisTNG/CV_0/")[:5]
# Out:
# ['snap_025.hdf5',
#  'snap_006.hdf5',
#  'snap_020.hdf5',
#  'snap_000.hdf5',
#  'snap_001.hdf5']

# %%
fof_path = "/global/cfs/cdirs/des/shubh/camels/~camels/FOF_Subfind/IllustrisTNG/LH_832/fof_subhalo_tab_000.hdf5"
# fof_path = "/global/cfs/cdirs/des/shubh/camels/Sims/IllustrisTNG/LH_15/snap_000.hdf5"
fof_file = h5py.File(fof_path, 'r')

# %%
list(fof_file['Header'].attrs.keys())
# Out:
# ['BoxSize',
#  'FlagDoubleprecision',
#  'Git_commit',
#  'Git_date',
#  'HubbleParam',
#  'Ngroups_ThisFile',
#  'Ngroups_Total',
#  'Nids_ThisFile',
#  'Nids_Total',
#  'Nsubgroups_ThisFile',
#  'Nsubgroups_Total',
#  'NumFiles',
#  'Omega0',
#  'OmegaLambda',
#  'Redshift',
#  'Time']

# %%
fof_file['Header'].attrs['Omega0'], fof_file['Header'].attrs['OmegaLambda'], fof_file['Header'].attrs['OmegaBaryon']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 fof_file['Header'].attrs['Omega0'], fof_file['Header'].attrs['OmegaLambda'], fof_file['Header'].attrs['OmegaBaryon']
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~/.conda/envs/simtim/lib/python3.9/site-packages/h5py/_hl/attrs.py:56, in AttributeManager.__getitem__(self, name)
#      52 @with_phil
#      53 def __getitem__(self, name):
#      54     """ Read the value of an attribute.
#      55     """
# ---> 56     attr = h5a.open(self._id, self._e(name))
#      57     shape = attr.shape
#      59     # shape is None for empty dataspaces
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5a.pyx:80, in h5py.h5a.open()
#
# KeyError: "Can't open attribute (can't locate attribute: 'OmegaBaryon')"

# %%
fof_file['Header'].attrs['HubbleParam']
# Out:
# 0.6711

# %%
list(map(lambda x: (x, fof_file['Header'].attrs[x]), fof_file['Header'].attrs.keys()))
# Out:
# [('BoxSize', 25000.0),
#  ('FlagDoubleprecision', 0),
#  ('Git_commit', b'4ab97a2c5659df3e83e01c53f8142816fc0db675'),
#  ('Git_date', b'Tue May 3 10:27:55 2016 +0200'),
#  ('HubbleParam', 0.6711),
#  ('Ngroups_ThisFile', 430),
#  ('Ngroups_Total', 430),
#  ('Nids_ThisFile', 37998),
#  ('Nids_Total', 37998),
#  ('Nsubgroups_ThisFile', 374),
#  ('Nsubgroups_Total', 374),
#  ('NumFiles', 1),
#  ('Omega0', 0.109),
#  ('OmegaLambda', 0.891),
#  ('Redshift', 5.977616828479627),
#  ('Time', 0.14331540762147194)]

# %% [markdown]
# # sim handler

# %%
import os
os._exit(0)

# %%
import numpy as np
import simim.siminterface as sim
# Out:
# Traceback (most recent call last):
#
#   File ~/.conda/envs/simtim/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3460 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[1], line 2
#     import simim.siminterface as sim
#
#   File /global/cfs/cdirs/des/shubh/timsim/simim/simim/siminterface/__init__.py:2
#     from . import illustris
#
#   File /global/cfs/cdirs/des/shubh/timsim/simim/simim/siminterface/illustris.py:360
#     print(i.)
#             ^
# SyntaxError: invalid syntax

# %%
cat = sim.illustris.illustris_catalogs('camels_CV_0')
# Out:
# /global/cfs/cdirs/des/shubh/timsim/simim/simim/siminterface/_rawsiminterface.py:151: UserWarning: No meta data for this simulation is available - run .download_meta
#   warnings.warn("No meta data for this simulation is available - run .download_meta")

# %%
cat.download_meta_camels(redownload=True)
# Out:
# 25 0.46525063335034633
# 6 2.6328051431518524
# 20 0.8613667026157819
# 0 5.994167484881114
# 1 4.995933468164624
# 18 1.0476023211521182
# 33 2.220446049250313e-16
# 26 0.3966142458048434
# 10 2.0020281392528516
# 29 0.21011695248665796
# 11 1.8597105714641113
# 32 0.04852362998180593
# 30 0.15411509849106242
# 5 2.8090820357141535
# 21 0.7741751440815878
# 27 0.33198166056503586
# 22 0.6910678790232259
# 15 1.3631687545470044
# 31 0.10005315893672084
# 28 0.2695879598716575
# 23 0.6128085535397709
# 2 3.9960945546982822
# 17 1.146959418533588
# 3 3.496184295585117
# 13 1.6011514303710488
# 19 0.951686971753962
# 9 2.1476974418769252
# 12 1.727368739905018
# 14 1.4778382807772075
# 4 2.9986464259849765
# 16 1.2538059104953225
# 7 2.464686001606746
# 24 0.5372601453713048
# 8 2.300435147841236
# [25, 6, 20, 0, 1, 18, 33, 26, 10, 29, 11, 32, 30, 5, 21, 27, 22, 15, 31, 28, 23, 2, 17, 3, 13, 19, 9, 12, 14, 4, 16, 7, 24, 8]
# Not provided a lower redshift snapshot
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 cat.download_meta_camels(redownload=True)
#
# File /global/cfs/cdirs/des/shubh/timsim/simim/simim/siminterface/illustris.py:361, in illustris_catalogs.download_meta_camels(self, redownload, sims_folder_path)
#     359 snap_meta_classes[-1].dif_lowerz_snap(0)
#     360 for i in range(len(snap_meta_classes)-1):
# --> 361     snap_meta_classes[i].dif_lowerz_snap(snap_meta_classes[i+1])
#     362     snap_meta_classes[i+1].dif_higherz_snap(snap_meta_classes[i])
#     364 snap_meta_dtype = [('index','i'),
#     365                    ('redshift','f'),
#     366                    ('redshift_min','f'),('redshift_max','f'),
#     367                    ('time_start','f'),('time_end','f'),
#     368                    ('distance_min','f'),('distance_max','f'),
#     369                    ('transverse_distance_min','f'),('transverse_distance_max','f')]
#
# File /global/cfs/cdirs/des/shubh/timsim/simim/simim/siminterface/_rawsiminterface.py:46, in snapshot.dif_lowerz_snap(self, other)
#      44 if self.redshift < other.redshift:
#      45     print("Not provided a lower redshift snapshot")
# ---> 46     raise Error
#      48 redshift_middle, time_middle = self.dif_snap(other)
#      49 self.redshift_min = redshift_middle
#
# NameError: name 'Error' is not defined

# %%
cat.format(remake=True,basic=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 cat.format(remake=True,basic=False)
#
# File /global/cfs/cdirs/des/shubh/timsim/simim/simim/siminterface/_rawsiminterface.py:221, in sim_catalogs.format(self, remake, basic)
#     218     for key in self.metadata.keys():
#     219         file.attrs[key] = self.metadata[key]
# --> 221     file.attrs['snapshots'] = self.snap_meta
#     223 # Now get the data
#     224 for snap in self.snaps:
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~/.conda/envs/simtim/lib/python3.9/site-packages/h5py/_hl/attrs.py:104, in AttributeManager.__setitem__(self, name, value)
#      96 @with_phil
#      97 def __setitem__(self, name, value):
#      98     """ Set a new attribute, overwriting any existing attribute.
#      99
#     100     The type and shape of the attribute are determined from the data.  To
#     101     use a specific type or shape, or to preserve the type of an attribute,
#     102     use the methods create() and modify().
#     103     """
# --> 104     self.create(name, data=value)
#
# File ~/.conda/envs/simtim/lib/python3.9/site-packages/h5py/_hl/attrs.py:181, in AttributeManager.create(self, name, data, shape, dtype)
#     179 # Make HDF5 datatype and dataspace for the H5A calls
#     180 if use_htype is None:
# --> 181     htype = h5t.py_create(original_dtype, logical=True)
#     182     htype2 = h5t.py_create(original_dtype)  # Must be bit-for-bit representation rather than logical
#     183 else:
#
# File h5py/h5t.pyx:1664, in h5py.h5t.py_create()
#
# File h5py/h5t.pyx:1688, in h5py.h5t.py_create()
#
# File h5py/h5t.pyx:1748, in h5py.h5t.py_create()
#
# TypeError: Object dtype dtype('O') has no native HDF5 equivalent
